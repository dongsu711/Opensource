# %%
import pandas as pd

# %%
df1 = pd.read_csv('CAvideos.csv')

# %%
df1
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# ...

# %%
df1.groupby(['trending_date']).mean()
# Out:
#                category_id         views         likes     dislikes  \
# trending_date
# 17.01.12         20.775000  1.118666e+06  40061.280000  2109.370000
# 17.02.12         20.050000  1.228575e+06  51420.915000  1776.725000
# 17.03.12         20.425000  1.503378e+06  58810.715000  2160.155000
# 17.04.12         20.256281  1.768771e+06  61930.954774  2608.351759
# 17.05.12         21.305000  1.776635e+06  61511.490000  2432.360000
# ...                    ...           ...           ...          ...
# 18.30.04         21.450000  1.397889e+06  41968.045000  2159.260000
# 18.30.05         20.695000  7.748078e+05  25151.020000  1062.535000
# 18.31.01         20.753927  1.124777e+06  37777.858639  2006.465969
# 18.31.03         20.185000  8.446839e+05  31232.480000   947.145000
# 18.31.05         20.940000  1.046798e+06  39382.200000  2145.710000
#
#                comment_count  comments_disabled  ratings_disabled  \
# trending_date
# ...

# %%
df1.groupby(['trending_date']).describe()
# Out:
#               category_id                                                     \
#                     count       mean       std  min    25%   50%   75%   max
# trending_date
# 17.01.12            200.0  20.775000  6.962525  1.0  20.00  24.0  24.0  43.0
# 17.02.12            200.0  20.050000  7.596449  1.0  17.00  23.0  24.0  43.0
# 17.03.12            200.0  20.425000  7.148418  1.0  20.00  24.0  24.0  28.0
# 17.04.12            199.0  20.256281  7.131496  1.0  19.50  24.0  24.0  28.0
# 17.05.12            200.0  21.305000  6.381661  1.0  20.00  24.0  24.0  43.0
# ...                   ...        ...       ...  ...    ...   ...   ...   ...
# 18.30.04            200.0  21.450000  6.010669  1.0  22.00  24.0  24.0  28.0
# 18.30.05            200.0  20.695000  7.181213  1.0  17.00  24.0  24.0  43.0
# 18.31.01            191.0  20.753927  6.557212  1.0  19.00  24.0  24.0  43.0
# 18.31.03            200.0  20.185000  7.396915  1.0  17.00  24.0  24.0  29.0
# ...

# %%
import seaborn as sns
anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import pandas as pd

# %%
df1=pd.read_csv('CAvideos.csv')
df1.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
import seaborn as sns
anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
anscombe.groupby('dataset').describe()
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
df1=pd.read_csv('CAvideos.csv')
df1.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
df1.index = pd.to_datetime(df1.index)

# %%
fig = plt.figure(figsize=(20, 12))
ax = fig.add_subplot(1,1,1)

ax.plot(df1['likes'], label='df1', color='b')
ax.plot(df1['dislikes'].iloc[1689:], label='df1', color='r')

ax.set_title('Youtbe likes & dislikes', fontsize=20)
ax.set_ylabel('likes&dislikes', fontsize=15)

ax.legend(fontsize=12, loc='best')
plt.show()

# %%
X = df1["likes"]
y = df1["dislikes"]
plt.plot(X,y,'o')
plt.show()
line_fitter = LinearRegression()
line_fitter.fit(X.values.reshape(-1,1),y)
line_fitter.predict([[1000]])
# Out:
# array([-535.64858806])

# %%
line_fitter.coef_
# Out:
# array([0.06595818])

# %%
line_fitter.intercept_
# Out:
# -601.6067716193309

# %%
plt.plot(X,y,'o')
plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)))
plt.show()
